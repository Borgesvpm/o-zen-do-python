# %% [markdown]
# # Exercícios

# %% [markdown]
# Crie uma variável chamada `caneta` e atribua seu valor a 10.

# %% [markdown]
# Calcule quando é 10 vezes 8 e coloque esse valor numa variável chamada `lapiseira`

# %% [markdown]
# Calcule a diferença entre as variáveis `lapiseira` e `caneta`, calculadas acima.

# %% [markdown]
# Defina se uma varíavel `x` é par ou ímpar.

# %% [markdown]
#  Sabendo que a fórmula da área de um retângulo é $base \times altura$, calcule a área de um retângulo com a base igual a 8 e altura igual a 6 e armazene a informação em uma variável chamada `area`. No final do programa, mostre a informação contida dentro da variável `area`.

# %% [markdown]
# Calcule a área do retângulo abaixo.
# ![0_010_rectangle.png](data:image/png;base64,...)

# %% [markdown]
# Calcule a área do triângulo abaixo.
# ![0_011_triangle.png](data:image/png;base64,...)

# %% [markdown]
# Faça uma calculadora de IMC (Índice de massa corporal). O IMC é calculado como:
#
# $ \frac{Peso}{Altura^2} $
#
# Salve o resultado dentro de uma variável `imc` e imprima o valor contido nessa variável para o usuário.

# %% [markdown]
# # Projetos

# %% [markdown]
# Sabe-se que uma população de bactérias dobra em 30 minutos, quando há abundância de recursos. Assumindo essas condições, e sabendo que a população de bactérias inicia-se com apenas um organismo, quanto tempo levará para que a população chegue em um milhão de organismos?

# %% [markdown]
# Uma loteria exige que o ticket, para ser vencedor em um sorteio, precisa acertar 6 números entre 60 opções possíveis (todos os números inteiros entre 1 e 60). Assumindo-se que uma pessoa queira comprar 1000 tickets de 6 números cada, qual será sua chance de vencer no sorteio?

# %% [markdown]
# Quantas moléculas de água existem em exatos 500 ml do líquido?
